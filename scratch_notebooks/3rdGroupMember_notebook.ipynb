# %%
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Sequential, regularizers
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.regularizers import l2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image
import os
import sys

pneumonia_filenames="..Data/train/PNEUMONIA"
normal_filenames = "..Data/train/NORMAL"

# %%
parent_dir =  os.path.dirname(os.getcwd())
train_path = os.path.join(parent_dir, 'Data/train')
test_path = os.path.join(parent_dir, 'Data/test')

# %%
pneumonia_filenames = os.listdir(os.path.join(train_path, 'pneumonia'))
normal_filenames = os.listdir(os.path.join(train_path, 'normal'))

# %%
pneumonia_filenames
# Out:
# ['BACTERIA-4038442-0001.jpeg',
#  'BACTERIA-8034950-0011.jpeg',
#  'BACTERIA-292199-0002.jpeg',
#  'BACTERIA-2092977-0003.jpeg',
#  'BACTERIA-4407438-0002.jpeg',
#  'BACTERIA-8093423-0001.jpeg',
#  'BACTERIA-880930-0002.jpeg',
#  'VIRUS-3443773-0006.jpeg',
#  'BACTERIA-9072988-0002.jpeg',
#  'VIRUS-9674936-0007.jpeg',
#  'VIRUS-1387612-0002.jpeg',
#  'BACTERIA-778527-0001.jpeg',
#  'BACTERIA-7564600-0004.jpeg',
#  'BACTERIA-1982399-0002.jpeg',
#  'BACTERIA-3246536-0004.jpeg',
#  'BACTERIA-4991468-0003.jpeg',
#  'BACTERIA-8188709-0003.jpeg',
#  'BACTERIA-112674-0001.jpeg',
#  'BACTERIA-3044214-0001.jpeg',
#  'VIRUS-6897628-0002.jpeg',
#  'VIRUS-385176-0010.jpeg',
#  'BACTERIA-4679582-0001.jpeg',
#  'BACTERIA-6162615-0002.jpeg',
#  'BACTERIA-1199786-0002.jpeg',
#  'BACTERIA-5150733-0007.jpeg',
#  'BACTERIA-516591-0002.jpeg',
#  'BACTERIA-3582443-0002.jpeg',
#  'VIRUS-149498-0002.jpeg',
#  'BACTERIA-2792838-0006.jpeg',
#  'BACTERIA-6944416-0001.jpeg',
#  'BACTERIA-4521338-0003.jpeg',
#  'BACTERIA-5401887-0003.jpeg',
#  'BACTERIA-1790048-0002.jpeg',
#  'BACTERIA-1083680-0003.jpeg',
#  'VIRUS-3659373-0001.jpeg',
#  'VIRUS-7201196-0006.jpeg',
#  'VIRUS-5988773-0004.jpeg',
#  'BACTERIA-1865585-0001.jpeg',
#  'BACTERIA-2426822-0004.jpeg',
#  'VIRUS-9727803-0002.jpeg',
#  'VIRUS-5619694-0002.jpeg',
#  'VIRUS-3807574-0007.jpeg',
#  'BACTERIA-5250831-0003.jpeg',
#  'BACTERIA-3690865-0002.jpeg',
#  'BACTERIA-8845554-0003.jpeg',
#  'VIRUS-9464756-0002.jpeg',
#  'BACTERIA-960851-0005.jpeg',
#  'BACTERIA-516152-0001.jpeg',
#  'VIRUS-5442456-0003.jpeg',
#  'BACTERIA-9074730-0001.jpeg',
#  'BACTERIA-8528032-0003.jpeg',
#  'BACTERIA-8720773-0001.jpeg',
#  'BACTERIA-2394612-0003.jpeg',
#  'BACTERIA-6121529-0002.jpeg',
#  'BACTERIA-6295192-0005.jpeg',
#  'BACTERIA-7882471-0006.jpeg',
#  'BACTERIA-960851-0004.jpeg',
#  'VIRUS-5284146-0003.jpeg',
#  'BACTERIA-8528032-0002.jpeg',
#  'VIRUS-9550884-0003.jpeg',
#  'BACTERIA-2394612-0002.jpeg',
#  'BACTERIA-8137600-0002.jpeg',
#  'VIRUS-1844534-0002.jpeg',
#  'BACTERIA-6295192-0004.jpeg',
#  'BACTERIA-9487238-0002.jpeg',
#  'VIRUS-1182905-0003.jpeg',
#  'BACTERIA-7849162-0002.jpeg',
#  'BACTERIA-5150733-0006.jpeg',
#  'BACTERIA-8276936-0001.jpeg',
#  'BACTERIA-5326583-0001.jpeg',
#  'VIRUS-7990865-0002.jpeg',
#  'BACTERIA-2427242-0001.jpeg',
#  'BACTERIA-3308986-0002.jpeg',
#  'BACTERIA-4521338-0002.jpeg',
#  'BACTERIA-3595250-0001.jpeg',
#  'BACTERIA-5401887-0002.jpeg',
#  'BACTERIA-1790048-0003.jpeg',
#  'VIRUS-5268802-0003.jpeg',
#  'VIRUS-6838768-0001.jpeg',
#  'VIRUS-7201196-0007.jpeg',
#  'BACTERIA-1083680-0002.jpeg',
#  'BACTERIA-8034950-0010.jpeg',
#  'BACTERIA-2092977-0002.jpeg',
#  'BACTERIA-8028911-0001.jpeg',
#  'BACTERIA-9072988-0003.jpeg',
#  'BACTERIA-880930-0003.jpeg',
#  'BACTERIA-5476259-0006.jpeg',
#  'BACTERIA-2474652-0001.jpeg',
#  'BACTERIA-7564600-0005.jpeg',
#  'BACTERIA-1982399-0003.jpeg',
#  'BACTERIA-6085366-0001.jpeg',
#  'BACTERIA-4629598-0001.jpeg',
#  'BACTERIA-6886752-0001.jpeg',
#  'BACTERIA-5719837-0001.jpeg',
#  'BACTERIA-3246536-0005.jpeg',
#  'BACTERIA-4991468-0002.jpeg',
#  'VIRUS-397009-0001.jpeg',
#  'BACTERIA-5602449-0001.jpeg',
#  'BACTERIA-8188709-0002.jpeg',
#  'VIRUS-3974793-0002.jpeg',
#  'BACTERIA-6076468-0001.jpeg',
#  'VIRUS-2426822-0007.jpeg',
#  'BACTERIA-7172433-0005.jpeg',
#  'BACTERIA-198200-0003.jpeg',
#  'BACTERIA-9727803-0001.jpeg',
#  'BACTERIA-324273-0003.jpeg',
#  'VIRUS-6715985-0003.jpeg',
#  ...]

# %%
#datagen = ImageDataGenerator(rotation_range=15)
#aug_iter=datagen.flow_from_directory(train_path,target_size=(256, 256),color_mode='grayscale')
#fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12,12))
#for i in range(3):
	# convert to unsigned integers
#	image = next(aug_iter)[0][0]
	# plot image
#	ax[i].imshow(image,cmap='gray')
#	ax[i].axis('off')

# %%
import matplotlib.image as mpimg

# %%
#import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
#img = mpimg.imread('../Data/train/NORMAL/NORMAL-2154341-0002.jpeg')
#imgplot= plt.imshow(img, cmap='gray')
#plt.show()

# %%
#plt.figure(figsize=(15,15))
#for i in range(30):
#    filename = normal_filenames[i]
#    img_addr = train_path + '/NORMAL/' + filename
#    img = Image.open(img_addr)
#    ax = plt.subplot(10,5,i+1)
#    plt.imshow(img, cmap='gray')

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
 
img_width, img_height = 256, 256

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %%
train_data_dir = train_path
validation_data_dir = test_path
nb_train_samples =400
nb_validation_samples = 100
epochs = 25
#50? seems to start overfitting
batch_size = 16

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# Metal device set to: Apple M2 Max
# 2023-05-09 09:38:08.457989: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-09 09:38:08.458836: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rotation_range=10)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_31144/4064417839.py:18: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# Epoch 1/25
# 12/12 [==============================] - 4s 346ms/step - loss: 0.5187 - accuracy: 0.8411 - val_loss: 0.6748 - val_accuracy: 0.5625
# Epoch 2/25
# 12/12 [==============================] - 4s 335ms/step - loss: 0.2198 - accuracy: 0.8958 - val_loss: 0.6450 - val_accuracy: 0.6250
# Epoch 3/25
# 12/12 [==============================] - 4s 343ms/step - loss: 0.2229 - accuracy: 0.9036 - val_loss: 0.6530 - val_accuracy: 0.5729
# Epoch 4/25
# 12/12 [==============================] - 4s 337ms/step - loss: 0.4179 - accuracy: 0.8594 - val_loss: 0.6596 - val_accuracy: 0.6979
# Epoch 5/25
# 12/12 [==============================] - 4s 330ms/step - loss: 0.3105 - accuracy: 0.9036 - val_loss: 0.6707 - val_accuracy: 0.6562
# Epoch 6/25
# 12/12 [==============================] - 4s 326ms/step - loss: 0.2511 - accuracy: 0.8932 - val_loss: 0.6439 - val_accuracy: 0.6458
# Epoch 7/25
# 12/12 [==============================] - 4s 337ms/step - loss: 0.3924 - accuracy: 0.8854 - val_loss: 0.6604 - val_accuracy: 0.7188
# Epoch 8/25
# 12/12 [==============================] - 4s 350ms/step - loss: 0.3698 - accuracy: 0.8958 - val_loss: 0.6765 - val_accuracy: 0.5833
# Epoch 9/25
# 12/12 [==============================] - 4s 329ms/step - loss: 0.1978 - accuracy: 0.9036 - val_loss: 0.6624 - val_accuracy: 0.5833
# Epoch 10/25
# 12/12 [==============================] - 4s 333ms/step - loss: 0.2184 - accuracy: 0.9141 - val_loss: 0.6275 - val_accuracy: 0.6562
# Epoch 11/25
# 12/12 [==============================] - 4s 331ms/step - loss: 0.4364 - accuracy: 0.8984 - val_loss: 0.6469 - val_accuracy: 0.6667
# Epoch 12/25
# 12/12 [==============================] - 4s 335ms/step - loss: 2.3516 - accuracy: 0.8958 - val_loss: 0.6491 - val_accuracy: 0.6667
# Epoch 13/25
# 12/12 [==============================] - 4s 339ms/step - loss: 0.2570 - accuracy: 0.9062 - val_loss: 0.6542 - val_accuracy: 0.6458
# Epoch 14/25
# 12/12 [==============================] - 4s 316ms/step - loss: 0.2165 - accuracy: 0.9185 - val_loss: 0.6424 - val_accuracy: 0.6458
# Epoch 15/25
# 12/12 [==============================] - 4s 326ms/step - loss: 0.1299 - accuracy: 0.9401 - val_loss: 0.6249 - val_accuracy: 0.6458
# Epoch 16/25
# 12/12 [==============================] - 4s 327ms/step - loss: 0.2755 - accuracy: 0.8958 - val_loss: 0.6514 - val_accuracy: 0.5521
# Epoch 17/25
# 12/12 [==============================] - 4s 325ms/step - loss: 1.0425 - accuracy: 0.8151 - val_loss: 0.6332 - val_accuracy: 0.6562
# Epoch 18/25
# 12/12 [==============================] - 4s 337ms/step - loss: 0.2357 - accuracy: 0.9115 - val_loss: 0.6244 - val_accuracy: 0.6667
# Epoch 19/25
# 12/12 [==============================] - 4s 335ms/step - loss: 0.1785 - accuracy: 0.9245 - val_loss: 0.6376 - val_accuracy: 0.6250
# Epoch 20/25
# 12/12 [==============================] - 4s 355ms/step - loss: 0.2056 - accuracy: 0.9245 - val_loss: 0.6404 - val_accuracy: 0.5312
# Epoch 21/25
# 12/12 [==============================] - 4s 349ms/step - loss: 1.8339 - accuracy: 0.8490 - val_loss: 0.6530 - val_accuracy: 0.6042
# Epoch 22/25
# 12/12 [==============================] - 4s 337ms/step - loss: 0.2832 - accuracy: 0.8802 - val_loss: 0.6522 - val_accuracy: 0.6146
# Epoch 23/25
# 12/12 [==============================] - 4s 333ms/step - loss: 0.2152 - accuracy: 0.8958 - val_loss: 0.6492 - val_accuracy: 0.6354
# Epoch 24/25
# 12/12 [==============================] - 4s 334ms/step - loss: 0.1400 - accuracy: 0.9297 - val_loss: 0.6563 - val_accuracy: 0.5833
# Epoch 25/25
# 12/12 [==============================] - 4s 350ms/step - loss: 1.2894 - accuracy: 0.8359 - val_loss: 0.6478 - val_accuracy: 0.5729

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 255, 255, 32)      416
#
#  activation_5 (Activation)   (None, 255, 255, 32)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 126, 126, 32)      4128
#
#  activation_6 (Activation)   (None, 126, 126, 32)      0
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 62, 62, 64)        8256
#
#  activation_7 (Activation)   (None, 62, 62, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 61504)             0
#
#  dense_2 (Dense)             (None, 64)                3936320
#
#  activation_8 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_9 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 3,949,185
# Trainable params: 3,949,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.save_weights('model_saved.h5')
#(dont save this model its the one that peaks at the testing data)

# %%
img_size = (256,256)
batch_size = 32
brightness = [0.8, 1.2]
vsplit = 0.2
rrange = 10
seed = 2023

train_datagen = ImageDataGenerator(validation_split=vsplit, rotation_range=rrange, fill_mode='nearest',
                                   brightness_range=brightness)

val_datagen = ImageDataGenerator()
print('----')
train_generator = train_datagen.flow_from_directory(train_path, target_size=img_size, batch_size=batch_size,
                                                    class_mode='binary', color_mode='grayscale', subset='training',
                                                    shuffle=True, seed=seed)
print('----')
val_generator = train_datagen.flow_from_directory(train_path, target_size=img_size, batch_size=batch_size,
                                                    class_mode='binary', color_mode='grayscale', subset='validation',
                                                    shuffle=True, seed=seed)
# Out:
# ----
# Found 4187 images belonging to 2 classes.
# ----
# Found 1045 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rotation_range=10)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_31144/4064417839.py:18: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# Epoch 1/25
# 2023-05-09 09:40:40.692160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 125.5058 - accuracy: 0.6016
# 2023-05-09 09:40:44.275800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 4s 321ms/step - loss: 125.5058 - accuracy: 0.6016 - val_loss: 0.6915 - val_accuracy: 0.5521
# Epoch 2/25
# 12/12 [==============================] - 4s 321ms/step - loss: 0.9625 - accuracy: 0.7292 - val_loss: 0.6904 - val_accuracy: 0.6562
# Epoch 3/25
# 12/12 [==============================] - 4s 330ms/step - loss: 0.4359 - accuracy: 0.8177 - val_loss: 0.6891 - val_accuracy: 0.6875
# Epoch 4/25
# 12/12 [==============================] - 4s 312ms/step - loss: 0.3574 - accuracy: 0.8255 - val_loss: 0.6839 - val_accuracy: 0.7708
# Epoch 5/25
# 12/12 [==============================] - 4s 334ms/step - loss: 1.8135 - accuracy: 0.6589 - val_loss: 0.6909 - val_accuracy: 0.6562
# Epoch 6/25
# 12/12 [==============================] - 4s 338ms/step - loss: 0.6880 - accuracy: 0.7214 - val_loss: 0.6903 - val_accuracy: 0.6146
# Epoch 7/25
# 12/12 [==============================] - 4s 325ms/step - loss: 0.6516 - accuracy: 0.7057 - val_loss: 0.6881 - val_accuracy: 0.6042
# Epoch 8/25
# 12/12 [==============================] - 4s 322ms/step - loss: 0.9304 - accuracy: 0.7500 - val_loss: 0.6836 - val_accuracy: 0.6562
# Epoch 9/25
# 12/12 [==============================] - 4s 326ms/step - loss: 1.0047 - accuracy: 0.7760 - val_loss: 0.6831 - val_accuracy: 0.5625
# Epoch 10/25
# 12/12 [==============================] - 4s 332ms/step - loss: 1.3529 - accuracy: 0.7500 - val_loss: 0.6871 - val_accuracy: 0.6354
# Epoch 11/25
# 12/12 [==============================] - 4s 314ms/step - loss: 0.3863 - accuracy: 0.8281 - val_loss: 0.6739 - val_accuracy: 0.7188
# Epoch 12/25
# 12/12 [==============================] - 4s 324ms/step - loss: 0.7884 - accuracy: 0.7917 - val_loss: 0.6834 - val_accuracy: 0.5729
# Epoch 13/25
# 12/12 [==============================] - 4s 328ms/step - loss: 0.5315 - accuracy: 0.7708 - val_loss: 0.6766 - val_accuracy: 0.6667
# Epoch 14/25
# 12/12 [==============================] - 4s 333ms/step - loss: 1.2160 - accuracy: 0.7630 - val_loss: 0.6747 - val_accuracy: 0.6250
# Epoch 15/25
# 12/12 [==============================] - 4s 328ms/step - loss: 1.1935 - accuracy: 0.7917 - val_loss: 0.6855 - val_accuracy: 0.6354
# Epoch 16/25
# 12/12 [==============================] - 4s 325ms/step - loss: 0.4319 - accuracy: 0.8646 - val_loss: 0.6765 - val_accuracy: 0.6250
# Epoch 17/25
# 12/12 [==============================] - 4s 333ms/step - loss: 0.3373 - accuracy: 0.8620 - val_loss: 0.6685 - val_accuracy: 0.6771
# Epoch 18/25
# 12/12 [==============================] - 4s 324ms/step - loss: 0.5896 - accuracy: 0.8723 - val_loss: 0.6718 - val_accuracy: 0.6250
# Epoch 19/25
# 12/12 [==============================] - 4s 329ms/step - loss: 0.7189 - accuracy: 0.8854 - val_loss: 0.6798 - val_accuracy: 0.6250
# Epoch 20/25
# 12/12 [==============================] - 4s 333ms/step - loss: 0.5517 - accuracy: 0.8724 - val_loss: 0.6724 - val_accuracy: 0.5938
# Epoch 21/25
# 12/12 [==============================] - 4s 326ms/step - loss: 0.4347 - accuracy: 0.8464 - val_loss: 0.6732 - val_accuracy: 0.5833
# Epoch 22/25
# 12/12 [==============================] - 4s 325ms/step - loss: 0.3167 - accuracy: 0.9141 - val_loss: 0.6512 - val_accuracy: 0.6875
# Epoch 23/25
# 12/12 [==============================] - 4s 320ms/step - loss: 0.2702 - accuracy: 0.9010 - val_loss: 0.6641 - val_accuracy: 0.5729
# Epoch 24/25
# 12/12 [==============================] - 4s 324ms/step - loss: 1.2433 - accuracy: 0.8646 - val_loss: 0.6668 - val_accuracy: 0.6354
# Epoch 25/25
# 12/12 [==============================] - 4s 323ms/step - loss: 0.2506 - accuracy: 0.9062 - val_loss: 0.6645 - val_accuracy: 0.5938

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 255, 255, 32)      416
#
#  activation_40 (Activation)  (None, 255, 255, 32)      0
#
#  max_pooling2d_24 (MaxPoolin  (None, 127, 127, 32)     0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 126, 126, 32)      4128
#
#  activation_41 (Activation)  (None, 126, 126, 32)      0
#
#  max_pooling2d_25 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 62, 62, 64)        8256
#
#  activation_42 (Activation)  (None, 62, 62, 64)        0
#
#  max_pooling2d_26 (MaxPoolin  (None, 31, 31, 64)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 61504)             0
#
#  dense_16 (Dense)            (None, 64)                3936320
#
#  activation_43 (Activation)  (None, 64)                0
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 1)                 65
#
#  activation_44 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 3,949,185
# Trainable params: 3,949,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('GideonModelv1')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: GideonModelv1/assets
# INFO:tensorflow:Assets written to: GideonModelv1/assets

# %%
model.save_weights('kevin_model_saved.h5')

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
 
img_width, img_height = 500, 500

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
    
train_data_dir = train_path
validation_data_dir = test_path
nb_train_samples =400
nb_validation_samples = 100
epochs = 25
#50? seems to start overfitting
batch_size = 16



#256 melted the computer
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
    rotation_range=10)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Epoch 1/25
# /var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_82542/4064417839.py:18: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# 2023-05-08 18:15:08.756251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - ETA: 0s - loss: 80.5192 - accuracy: 0.7450
# 2023-05-08 18:15:16.551234: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 9s 320ms/step - loss: 80.5192 - accuracy: 0.7450 - val_loss: 0.6679 - val_accuracy: 0.6354
# Epoch 2/25
# 25/25 [==============================] - 8s 311ms/step - loss: 0.8017 - accuracy: 0.8375 - val_loss: 0.6690 - val_accuracy: 0.6042
# Epoch 3/25
# 25/25 [==============================] - 8s 314ms/step - loss: 2.3572 - accuracy: 0.7675 - val_loss: 0.6491 - val_accuracy: 0.6250
# Epoch 4/25
# 25/25 [==============================] - 8s 318ms/step - loss: 0.8187 - accuracy: 0.7900 - val_loss: 0.7128 - val_accuracy: 0.5104
# Epoch 5/25
# 25/25 [==============================] - 8s 319ms/step - loss: 1.4115 - accuracy: 0.7800 - val_loss: 0.6781 - val_accuracy: 0.6458
# Epoch 6/25
# 25/25 [==============================] - 8s 311ms/step - loss: 0.4506 - accuracy: 0.8500 - val_loss: 0.6707 - val_accuracy: 0.8021
# Epoch 7/25
# 25/25 [==============================] - 8s 312ms/step - loss: 0.9480 - accuracy: 0.8000 - val_loss: 0.6904 - val_accuracy: 0.3958
# Epoch 8/25
# 25/25 [==============================] - 8s 317ms/step - loss: 0.4304 - accuracy: 0.8300 - val_loss: 0.6827 - val_accuracy: 0.6771
# Epoch 9/25
# 25/25 [==============================] - 8s 321ms/step - loss: 0.7810 - accuracy: 0.7875 - val_loss: 0.6654 - val_accuracy: 0.7500
# Epoch 10/25
# 25/25 [==============================] - 8s 318ms/step - loss: 0.8294 - accuracy: 0.8475 - val_loss: 0.6345 - val_accuracy: 0.7083
# Epoch 11/25
# 25/25 [==============================] - 8s 321ms/step - loss: 0.5634 - accuracy: 0.7925 - val_loss: 0.6648 - val_accuracy: 0.5938
# Epoch 12/25
# 25/25 [==============================] - 8s 318ms/step - loss: 0.3510 - accuracy: 0.8700 - val_loss: 0.6655 - val_accuracy: 0.6354
# Epoch 13/25
# 25/25 [==============================] - 8s 320ms/step - loss: 1.3163 - accuracy: 0.8475 - val_loss: 0.6504 - val_accuracy: 0.6771
# Epoch 14/25
# 25/25 [==============================] - 8s 318ms/step - loss: 0.5335 - accuracy: 0.8225 - val_loss: 0.6633 - val_accuracy: 0.4167
# Epoch 15/25
# 25/25 [==============================] - 8s 310ms/step - loss: 0.8489 - accuracy: 0.8475 - val_loss: 0.6952 - val_accuracy: 0.4062
# Epoch 16/25
# 25/25 [==============================] - 8s 318ms/step - loss: 1.6293 - accuracy: 0.6750 - val_loss: 0.6954 - val_accuracy: 0.4583
# Epoch 17/25
# 25/25 [==============================] - 8s 317ms/step - loss: 0.7017 - accuracy: 0.2525 - val_loss: 0.6973 - val_accuracy: 0.3125
# Epoch 18/25
# 25/25 [==============================] - 8s 316ms/step - loss: 0.6960 - accuracy: 0.2750 - val_loss: 0.6933 - val_accuracy: 0.3542
# Epoch 19/25
# 25/25 [==============================] - 8s 320ms/step - loss: 0.6907 - accuracy: 0.7150 - val_loss: 0.6913 - val_accuracy: 0.5833
# Epoch 20/25
# 25/25 [==============================] - 8s 318ms/step - loss: 0.6850 - accuracy: 0.7450 - val_loss: 0.6896 - val_accuracy: 0.5833
# Epoch 21/25
# 25/25 [==============================] - 8s 321ms/step - loss: 0.6807 - accuracy: 0.7325 - val_loss: 0.6833 - val_accuracy: 0.6562
# Epoch 22/25
# 25/25 [==============================] - 8s 321ms/step - loss: 0.6766 - accuracy: 0.7250 - val_loss: 0.6813 - val_accuracy: 0.6458
# Epoch 23/25
# 25/25 [==============================] - 8s 323ms/step - loss: 0.6732 - accuracy: 0.7150 - val_loss: 0.6764 - val_accuracy: 0.6667
# Epoch 24/25
# 25/25 [==============================] - 8s 319ms/step - loss: 0.6621 - accuracy: 0.7725 - val_loss: 0.6801 - val_accuracy: 0.6146
# Epoch 25/25
# 25/25 [==============================] - 8s 320ms/step - loss: 0.6600 - accuracy: 0.7500 - val_loss: 0.6625 - val_accuracy: 0.7188

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
 
img_width, img_height = 500, 500

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
    
train_data_dir = train_path
validation_data_dir = test_path
nb_train_samples =400
nb_validation_samples = 100
epochs = 25
#50? seems to start overfitting
batch_size = 16



#256 melted the computer
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rotation_range=10)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_82542/2685172367.py:22: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# Epoch 1/25
# 2023-05-08 18:21:06.818481: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - ETA: 0s - loss: 161.2533 - accuracy: 0.6450
# 2023-05-08 18:21:17.820743: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 25/25 [==============================] - 12s 466ms/step - loss: 161.2533 - accuracy: 0.6450 - val_loss: 0.6857 - val_accuracy: 0.6771
# Epoch 2/25
# 25/25 [==============================] - 12s 466ms/step - loss: 0.7238 - accuracy: 0.8000 - val_loss: 0.6778 - val_accuracy: 0.6146
# Epoch 3/25
# 25/25 [==============================] - 12s 461ms/step - loss: 0.8419 - accuracy: 0.7700 - val_loss: 0.6551 - val_accuracy: 0.6458
# Epoch 4/25
# Epoch 24/25
# 25/25 [==============================] - 12s 471ms/step - loss: 2.0842 - accuracy: 0.7625 - val_loss: 0.6288 - val_accuracy: 0.6458
# Epoch 25/25
# 25/25 [==============================] - 12s 460ms/step - loss: 0.4631 - accuracy: 0.8500 - val_loss: 0.6516 - val_accuracy: 0.6562

# %%
img_width, img_height = 1000, 1000

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
    
    
train_data_dir = train_path
validation_data_dir = test_path
nb_train_samples =400
nb_validation_samples = 100
epochs = 25
#50? seems to start overfitting
batch_size = 16



#256 melted the computer
model = Sequential()
model.add(Conv2D(50, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rotation_range=10)
 
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
 
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 5232 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_31144/2685172367.py:22: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
# Epoch 1/25
# 2023-05-09 17:20:18.642110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 8.0939 - accuracy: 0.8047
# 2023-05-09 17:20:22.397808: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 4s 322ms/step - loss: 8.0939 - accuracy: 0.8047 - val_loss: 0.6252 - val_accuracy: 0.8438
# Epoch 2/25
# 12/12 [==============================] - 4s 330ms/step - loss: 0.2977 - accuracy: 0.9219 - val_loss: 0.6335 - val_accuracy: 0.7500
# Epoch 3/25
# 12/12 [==============================] - 4s 338ms/step - loss: 0.3998 - accuracy: 0.8958 - val_loss: 0.6454 - val_accuracy: 0.9167
# Epoch 4/25
# 12/12 [==============================] - 4s 334ms/step - loss: 0.1729 - accuracy: 0.9245 - val_loss: 0.6451 - val_accuracy: 0.7708
# Epoch 5/25
# 12/12 [==============================] - 4s 329ms/step - loss: 0.1492 - accuracy: 0.9193 - val_loss: 0.6461 - val_accuracy: 0.6562
# Epoch 6/25
# 12/12 [==============================] - 4s 331ms/step - loss: 0.2374 - accuracy: 0.8724 - val_loss: 0.6579 - val_accuracy: 0.5938
# Epoch 7/25
# 12/12 [==============================] - 4s 327ms/step - loss: 0.3922 - accuracy: 0.9010 - val_loss: 0.6432 - val_accuracy: 0.9375
# Epoch 8/25
# 12/12 [==============================] - 4s 330ms/step - loss: 0.3442 - accuracy: 0.9089 - val_loss: 0.6305 - val_accuracy: 0.7083
# Epoch 9/25
# 12/12 [==============================] - 4s 323ms/step - loss: 0.1968 - accuracy: 0.9297 - val_loss: 0.6290 - val_accuracy: 0.7396
# Epoch 10/25
# 12/12 [==============================] - 4s 327ms/step - loss: 0.1908 - accuracy: 0.9349 - val_loss: 0.6489 - val_accuracy: 0.6146
# Epoch 11/25
# 12/12 [==============================] - 4s 330ms/step - loss: 0.1875 - accuracy: 0.9271 - val_loss: 0.6430 - val_accuracy: 0.6250
# Epoch 12/25
# 12/12 [==============================] - 4s 338ms/step - loss: 0.3659 - accuracy: 0.8646 - val_loss: 0.6577 - val_accuracy: 0.6042
# Epoch 13/25
# 12/12 [==============================] - 4s 332ms/step - loss: 0.3342 - accuracy: 0.9010 - val_loss: 0.6512 - val_accuracy: 0.6667
# Epoch 14/25
# 12/12 [==============================] - 4s 322ms/step - loss: 0.1654 - accuracy: 0.9239 - val_loss: 0.5949 - val_accuracy: 0.6667
# Epoch 15/25
# 12/12 [==============================] - 4s 328ms/step - loss: 0.3419 - accuracy: 0.9219 - val_loss: 0.6105 - val_accuracy: 0.6979
# Epoch 16/25
# 12/12 [==============================] - 4s 329ms/step - loss: 0.4001 - accuracy: 0.8958 - val_loss: 0.6099 - val_accuracy: 0.6875
# Epoch 17/25
# 12/12 [==============================] - 4s 342ms/step - loss: 0.3492 - accuracy: 0.9141 - val_loss: 0.6500 - val_accuracy: 0.5938
# Epoch 18/25
# 12/12 [==============================] - 4s 365ms/step - loss: 0.3201 - accuracy: 0.9141 - val_loss: 0.6373 - val_accuracy: 0.6250
# Epoch 19/25
# 12/12 [==============================] - 4s 324ms/step - loss: 0.2441 - accuracy: 0.9271 - val_loss: 0.6306 - val_accuracy: 0.6354
# Epoch 20/25
# 12/12 [==============================] - 4s 341ms/step - loss: 0.2875 - accuracy: 0.9089 - val_loss: 0.6443 - val_accuracy: 0.5938
# Epoch 21/25
# 12/12 [==============================] - 4s 319ms/step - loss: 0.1280 - accuracy: 0.9297 - val_loss: 0.5997 - val_accuracy: 0.6562
# Epoch 22/25
# 12/12 [==============================] - 4s 324ms/step - loss: 0.4931 - accuracy: 0.9036 - val_loss: 0.5668 - val_accuracy: 0.7188
# Epoch 23/25
# 12/12 [==============================] - 4s 327ms/step - loss: 0.1951 - accuracy: 0.9401 - val_loss: 0.6374 - val_accuracy: 0.5729
# Epoch 24/25
# 12/12 [==============================] - 4s 319ms/step - loss: 0.3290 - accuracy: 0.9297 - val_loss: 0.6192 - val_accuracy: 0.6667
# Epoch 25/25
# 12/12 [==============================] - 4s 337ms/step - loss: 0.2304 - accuracy: 0.9062 - val_loss: 0.6135 - val_accuracy: 0.6875

# %%
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, LayerNormalization, \
                                    BatchNormalization, Activation, MaxPool2D, AveragePooling2D
from tensorflow.keras.models import Model

# %%
def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def ResNet34(shape = (128, 128, 1), classes = 3):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    # Step 2 (Initial Conv layer along with maxPool)
    x = Conv2D(128, kernel_size=(3,3), strides=2, padding='same')(x_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPool2D(pool_size=(2,2), strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 128
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = AveragePooling2D((2,2), padding = 'same')(x)
    x = Flatten()(x)
    x = Dense(512, activation = 'relu')(x)
    x = Dense(classes, activation = 'softmax')(x)
    model = Model(inputs = x_input, outputs = x, name = "Model2")
    return model

# %%
model3 = ResNet34()

# %%
img_size = (128, 128)
batch_size = 32
brightness = [0.8, 1.2]
vsplit = 0.2
rrange = 10
seed = 2023

train_datagen = ImageDataGenerator(validation_split=vsplit, rotation_range=rrange, fill_mode='nearest',
                                   brightness_range=brightness)

print('----')
train_generator = train_datagen.flow_from_directory(train_path, target_size=img_size, batch_size=batch_size,
                                                    class_mode='categorical', color_mode='grayscale', subset='training',
                                                    shuffle=True, seed=seed)
print('----')
val_generator = train_datagen.flow_from_directory(train_path, target_size=img_size, batch_size=batch_size,
                                                    class_mode='categorical', color_mode='grayscale', subset='validation',
                                                    shuffle=True, seed=seed)

print('----')
test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(test_path, target_size=img_size, batch_size=batch_size,
                                                  class_mode='categorical', color_mode='grayscale')
# Out:
# ----
# Found 4187 images belonging to 2 classes.
# ----
# Found 1045 images belonging to 2 classes.
# ----
# Found 624 images belonging to 2 classes.

# %%
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['Recall', 'Precision', 'accuracy'])

# %%
model3.fit(train_generator, epochs=20, workers=10, validation_data=val_generator, validation_steps=100//batch_size)
# Out:
# Epoch 1/20
# 2023-05-09 17:25:55.393983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 model3.fit(train_generator, epochs=20, workers=10, validation_data=val_generator, validation_steps=100//batch_size)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'categorical_crossentropy/softmax_cross_entropy_with_logits' defined at (most recent call last):
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_31144/316147809.py", line 1, in <module>
#       model3.fit(train_generator, epochs=20, workers=10, validation_data=val_generator, validation_steps=100//batch_size)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 890, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 948, in compute_loss
#       return self.compiled_loss(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/compile_utils.py", line 201, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 139, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 243, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 1787, in categorical_crossentropy
#       return backend.categorical_crossentropy(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/backend.py", line 5134, in categorical_crossentropy
#       return tf.nn.softmax_cross_entropy_with_logits(
# Node: 'categorical_crossentropy/softmax_cross_entropy_with_logits'
# Detected at node 'categorical_crossentropy/softmax_cross_entropy_with_logits' defined at (most recent call last):
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/67/dbt0zf1x41q5bnr6syjzgy5w0000gn/T/ipykernel_31144/316147809.py", line 1, in <module>
#       model3.fit(train_generator, epochs=20, workers=10, validation_data=val_generator, validation_steps=100//batch_size)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 890, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py", line 948, in compute_loss
#       return self.compiled_loss(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/compile_utils.py", line 201, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 139, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 243, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/losses.py", line 1787, in categorical_crossentropy
#       return backend.categorical_crossentropy(
#     File "/Users/Gideon/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/backend.py", line 5134, in categorical_crossentropy
#       return tf.nn.softmax_cross_entropy_with_logits(
# Node: 'categorical_crossentropy/softmax_cross_entropy_with_logits'
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  logits and labels must be broadcastable: logits_size=[32,3] labels_size=[32,2]
# 	 [[{{node categorical_crossentropy/softmax_cross_entropy_with_logits}}]]
# 	 [[assert_greater_equal/Assert/AssertGuard/pivot_f/_3/_49]]
#   (1) INVALID_ARGUMENT:  logits and labels must be broadcastable: logits_size=[32,3] labels_size=[32,2]
# 	 [[{{node categorical_crossentropy/softmax_cross_entropy_with_logits}}]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_54974]
